# %% [markdown]
# # Cities for Young Adults analysis

# %% [markdown]
# The datasets used in this presentation were from Office for National Statistics and represent Gross Value added in terms of Nomenclature of Territorial Units for Statistics (NUTS). More information on NUTS3 can be found here:
#
# https://en.wikipedia.org/wiki/Nomenclature_of_Territorial_Units_for_Statistics
#
# The second dataset used in this presentation is from The Best Place to Live as a Young Adult, evaluated by Comparethemarket. For the full dataset, the link can be found here:
#
# https://www.comparethemarket.com/home-insurance/content/best-uk-city-for-young-adults/
#
# For this project, I first used Python and BeautifulSoup to scrape the data of their respective web pages.
#
# Then, I used Python to aggregate summary statistics within Jupyter Notebook. In doing so, I discovered.
#
# * Which regions have the highest proportion of young adults?
# * Which regions have the highest 4G coverage?
# * What was the average score per region?
# * Which regions and cities spend the highest proportion of their salary on rent?
# * Which variables have the highest correlation with Mental wellbeing?
#
# After this, I wanted to focus more on the economic output of each region. To achieve this, I performed an inner join to merge the tables into a single dataframe. I wanted to discover,
#
# * Does a higher value of rent correlate with a higher gross value added per head?
# * Is there a correlation between the Young adult percentage and productivity of a city?
# * Are cities with a higher Gross Value added ranked as better for young adults?

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
wiki_url = 'https://en.wikipedia.org/wiki/List_of_UK_cities_by_GVA'
table_class = 'wikitable sortable jquery-tablesorter'
response = requests.get(wiki_url)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# This 200 tells us that it is legal to download the contents of the table.

# %%
soup = BeautifulSoup(response.text, 'html.parser')
all_tables = soup.findAll('table', {'class': 'wikitable'})
wiki_tables = []
for i in all_tables:
    wiki_tables.append(i)
city_table = wiki_tables[-1]
city_table
# Out:
# <table class="wikitable sortable" style="float:center; font-size:85%; margin-left:15px;">
# <caption><i>GVA and GVA per head for 2015</i>
# </caption>
# <tbody><tr>
# <th>Rank</th>
# <th>City/Conurbation</th>
# <th>GVA <br/>(£ millions)</th>
# <th>Growth (%) <br/>2009-15</th>
# <th>GVA <br/>per head</th>
# <th>GVA per employee <br/>(productivity)
# </th></tr>
# <tr style="text-align:right;">
# <td>1</td>
# <td style="text-align:left;"><a href="/wiki/Economy_of_London" title="Economy of London">London</a><sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[note 1]</a></sup></td>
# <td>378,424</td>
# <td style="text-align:left;"><img alt="Increase" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" title="Increase" width="11"/> 30.6</td>
# <td>£ 43,629</td>
# <td>£ 70,392
# </td></tr>
# <tr style="text-align:right;">
# <td>2</td>
# <td style="text-align:left;"><a href="/wiki/Economy_of_Manchester" title="Economy of Manchester">Greater Manchester</a><sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[note 2]</a></sup></td>
# <td>59,606</td>
# <td style="text-align:left;"><img alt="Increase" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" title="Increase" width="11"/> 17.5</td>
# <td>£ 21,626</td>
# <td>£ 44,974
# </td></tr>
# <tr style="text-align:right;">
# <td>3</td>
# <td style="text-align:left;"><a href="/wiki/Economy_of_Birmingham" title="Economy of Birmingham">Birmingham</a></td>
# <td>24,790</td>
# <td style="text-align:left;"><img alt="Increase" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" title="Increase" width="11"/> 21.7</td>
# <td>£ 22,307</td>
# <td>£ 45,934
# </td></tr>
# <tr style="text-align:right;">
# <td>4</td>
# <td style="text-align:left;"><a href="/wiki/Economy_of_Leeds" title="Economy of Leeds">Leeds</a></td>
# <td>21,260</td>
# <td style="text-align:left;"><img alt="Increase" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" title="Increase" width="11"/> 14.6</td>
# <td>£ 27,466</td>
# <td>£ 45,790
# </td></tr>
# <tr style="text-align:right;">
# <td>5</td>
# <td style="text-align:left;"><a href="/wiki/Glasgow" title="Glasgow">Glasgow</a></td>
# <td>19,624</td>
# <td style="text-align:left;"><img alt="Increase" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" title="Increase" width="11"/> 12.8</td>
# <td>£ 32,305</td>
# <td>£ 46,914
# </td></tr>
# <tr style="text-align:right;">
# <td>6</td>
# <td style="text-align:left;"><a href="/wiki/Economy_of_Edinburgh" title="Economy of Edinburgh">Edinburgh</a></td>
# <td>18,437</td>
# <td style="text-align:left;"><img alt="Increase" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" title="Increase" width="11"/>
"><img alt="Increase" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" title="Increase" width="11"/> 16.1</td>
# <td>£ 18,577</td>
# <td>£ 38,584
# </td></tr></tbody></table>

# %%
df = pd.read_html(str(city_table))
#convert list to dataframe
df = pd.DataFrame(df[0])
#clean the data 
df = df.rename(columns={'City/Conurbation': 'City'})
city_list = []
for city in df['City']:
    city_list.append(str(city).replace('[','').replace(']','').replace('note','').replace('1','').replace('2', '').replace('3', '').replace('Greater Manchester', 'Manchester').replace('Cardiff and Vale of Glamorgan', 'Cardiff').strip(' '))
df['City'] = city_list

# %%
df
# Out:
#     Rank                   City  GVA (£ millions)  Growth (%) 2009-15  \
# 0      1                 London            378424                30.6
# 1      2             Manchester             59606                17.5
# 2      3             Birmingham             24790                21.7
# 3      4                  Leeds             21260                14.6
# 4      5                Glasgow             19624                12.8
# 5      6              Edinburgh             18437                10.6
# 6      7               Tyneside             18224                21.1
# 7      8                Bristol             13862                22.4
# 8      9              Sheffield             11300                11.2
# 9     10                Cardiff             11044                12.4
# 10    11              Liverpool             10907                 0.6
# 11    12          Milton Keynes             10884                39.3
# 12    13                Belfast              9982                15.3
# 13    14               Bradford              9504                10.6
# 14    15             Nottingham              8816                16.8
# 15    16  Bournemouth and Poole              8209                15.8
# 16    17               Coventry              7655                31.1
# 17    18              Leicester              7473                26.1
# 18    19        Brighton & Hove              7129                26.7
# 19    20                  Derby              6932                28.0
# 20    21              Wakefield              6621                20.2
# 21    22            Southampton              5873                16.4
# 22    23             Sunderland              5745                18.8
# 23    24             Portsmouth              5344                13.0
# 24    25           Peterborough              5382                22.5
# 25    26               Plymouth              5192                20.4
# 26    27     Kingston upon Hull              5129                 4.3
# 27    28                   York              5068                12.8
# 28    29                  Luton              4888                 9.0
# 29    30         Stoke-on-Trent              4763                24.0
# 30    31          Wolverhampton              4625                13.5
# 31    32                Swansea              4503                16.1
#
#    GVA per head GVA per employee (productivity)
# 0      £ 43,629                        £ 70,392
# 1      £ 21,626                        £ 44,974
# 2      £ 22,307                        £ 45,934
# 3      £ 27,466                        £ 45,790
# 4      £ 32,305                        £ 46,914
# 5      £ 36,963                        £ 55,196
# 6      £ 21,566                        £ 42,788
# 7      £ 30,850                        £ 48,090
# 8      £ 19,833                        £ 41,695
# 9      £ 22,783                        £ 42,181
# 10     £ 22,790                        £ 43,396
# 11     £ 41,581                        £ 62,247
# 12     £ 35,023                        £ 44,520
# 13     £ 17,892                        £ 43,507
# 14     £ 27,645                        £ 37,948
# 15      £23,787                        £ 46,571
# 16     £ 22,165                        £ 45,706
# 17     £ 21,812                        £ 40,466
# 18     £ 24,989                        £ 45,348
# 19     £ 27,266                        £ 51,932
# 20     £ 19,837                        £ 42,590
# 21     £ 23,535                        £ 45,882
# 22     £ 20,728                        £ 46,671
# 23     £ 25,236                        £ 46,405
# 24     £ 27,745                        £ 46,482
# 25     £ 19,762                        £ 40,322
# 26     £ 19,803                        £ 41,246
# 27     £ 24,499                        £ 45,547
# 28     £ 22,766                        £ 51,701
# 29     £ 18,926                        £ 39,707
# 30     £ 18,179                        £ 42,117
# 31     £ 18,577                        £ 38,584

# %%
young_adult_table = 'https://www.comparethemarket.com/home-insurance/content/best-uk-city-for-young-adults/'

# %%
#Import second dataframe from excel file 
xl = pd.ExcelFile("young_adult_rankings.xlsx")
df2 = xl.parse('Sheet1')
df2
# Out:
#     Rank                 City                    Region  \
# 0      1            Edinburgh                  Scotland
# 1      2              Reading                South East
# 2      3                Derby             East Midlands
# 3      4           Manchester                North West
# 4      5              Bristol                South West
# 5      6             Aberdeen                  Scotland
# 6      7              Glasgow                  Scotland
# 7      8            Liverpool                North West
# 8      9    Brighton and Hove                South East
# 9     10  Newcastle upon Tyne                North East
# 10    11             Plymouth                South West
# 11    12             Coventry             West Midlands
# 12    13           Nottingham             East Midlands
# 13    14          Southampton                South East
# 14    15          Northampton             East Midlands
# 15    16                Leeds  Yorkshire and the Humber
# 16    17          Bournemouth                South West
# 17    18              Cardiff                     Wales
# 18    19                Luton                      East
# 19    20               London                    London
# 20    21            Leicester             East Midlands
# 21    22           Portsmouth                South East
# 22    23   Kingston upon Hull  Yorkshire and the Humber
# 23    24            Sheffield  Yorkshire and the Humber
# 24    25           Birmingham             West Midlands
# 25    26        Wolverhampton             West Midlands
# 26    27       Stoke-on-Trent             West Midlands
# 27    28             Bradford  Yorkshire and the Humber
#
#     Young adult population  Rent  Salary  Mental wellbeing  4G coverage  \
# 0                   0.3256   714   25720             25.27       0.8638
# 1                   0.2999  1101   27126             25.47       0.9395
# 2                   0.2556   654   26000             25.19       0.8847
# 3                   0.3857   689   21896             25.23       0.8971
# 4                   0.3535   829   24122             25.28       0.8323
# 5                   0.3143   714   24676             25.27       0.8077
# 6                   0.3289   714   22325             25.27       0.9102
# 7                   0.3265   689   22338             25.23       0.8987
# 8                   0.3332  1101   24469             25.47       0.8073
# 9                   0.3531   567   22054             24.84       0.8966
# 10                  0.2710   829   22526             25.28       0.7989
# 11                  0.3417   702   24291             25.00       0.8196
# 12                  0.3789   654   19552             25.19       0.8824
# 13                  0.3532  1101   22007             25.47       0.9026
# 14                  0.2422   654   22945             25.19       0.8642
# 15                  0.2955   617   23115             25.02       0.8089
# 16                  0.2274   829   23661             25.28       0.8614
# 17                  0.3296   660   23411             25.10       0.7108
# 18                  0.2634   930   21652             25.50       0.9029
# 19                  0.2854  2059   30311             25.16       0.9306
# 20                  0.3277   654   18958             25.19       0.8904
# 21                  0.3244  1101   22039             25.47       0.7808
# 22                  0.2863   617   19262             25.02       0.9346
# 23                  0.3054   617   22321             25.02       0.7346
# 24                  0.2950   702   22225             25.00       0.8195
# 25                  0.2439   702   21600             25.00       0.8714
# 26                  0.2523   702   22082             25.00       0.7641
# 27                  0.2324   617   21126             25.02       0.7818
#
#     Nightlife  Total Score / 100
# 0          12              72.05
# 1           9              71.40
# 2          11              69.00
# 3          10              66.13
# 4           9              65.44
# 5           8              65.28
# 6          10              65.27
# 7          13              64.96
# 8          13              63.22
# 9          12              62.42
# 10         27              62.12
# 11          2              60.59
# 12         10              60.23
# 13          7              60.09
# 14          6              58.37
# 15          7              58.09
# 16          6              57.24
# 17          6              57.01
# 18          3              55.80
# 19          5              55.17
# 20          7              55.14
# 21          9              54.45
# 22          9              54.07
# 23          7              53.84
# 24          4              53.74
# 25          6              52.11
# 26          9              50.59
# 27          4              47.60

# %% [markdown]
# ### Which regions have the highest proportion of young adults?

# %%
df2.groupby('Region')['Young adult population'].mean().sort_values(ascending=False)
# Out:
# Region
# North West                  0.356100
# North East                  0.353100
# Wales                       0.329600
# South East                  0.327675
# Scotland                    0.322933
# East Midlands               0.301100
# London                      0.285400
# South West                  0.283967
# West Midlands               0.283225
# Yorkshire and the Humber    0.279900
# East                        0.263400
# Name: Young adult population, dtype: float64

# %% [markdown]
# * The North West has the highest proportion of adults, followed closely by the North East. The East has the smallest proportion.
# * London has 2 percent fewer Young adults than the national average.

# %%
df2['Young adult population'].mean() - 0.285400
# Out:
# 0.01931428571428573

# %% [markdown]
# ### Which regions have the highest 4G coverage?

# %%
df2['4G coverage'].mean()
# Out:
# 0.849907142857143

# %%
df2.groupby('Region')['4G coverage'].mean().sort_values(ascending=False)
# Out:
# Region
# London                      0.930600
# East                        0.902900
# North West                  0.897900
# North East                  0.896600
# East Midlands               0.880425
# Scotland                    0.860567
# South East                  0.857550
# South West                  0.830867
# West Midlands               0.818650
# Yorkshire and the Humber    0.814975
# Wales                       0.710800
# Name: 4G coverage, dtype: float64

# %% [markdown]
# * London has by far the highest 4G coverage with 93%
# * The lowest is Wales with 71%
# * The average across the UK is 85%

# %% [markdown]
# ### What was the average score per region?

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10, 8))
df2.groupby('Region')['Total Score / 100'].mean().sort_values(ascending=False).plot(kind='bar')
plt.title('Average score per Region')
plt.xlabel('Region')
plt.ylabel('Average Score')
plt.xticks(rotation=45);

# %% [markdown]
# * Scotland receives the highest score per Region, with Yorkshire ad the Humber witht the lowest average score
# * The East Midlands is the region closest to the median score
# * London scored much lower than the average score with 55 points on average

# %% [markdown]
# ### Which regions and cities spend the highest proportion of their salary on rent?

# %%
# Create a new column as a calculated field to store values for percentage of salary spent on rent
df2['Percent of Salary on Rent'] = df2['Rent'] / (df2['Salary'] / 12) * 100

# %%
df2
plt.figure(figsize=(15, 10))
plt.title('Proportion of monthly salary spent on Rent')
sns.barplot(x = 'City', y = 'Percent of Salary on Rent', data = df2, order=df2.sort_values('Percent of Salary on Rent').City, palette='pastel')
plt.xticks(rotation=45);

# %% [markdown]
# * In London, a eye-watering 82% of monthly salary in spent on rent.
# * At first glance, it would seem the most expensive cities are predominantly in the South of England, occupying the majority of the worst offenders
# * Conversely, the those living in the North of England is the cheapest, almost 60% cheaper than living in the South/London

# %% [markdown]
# ### Which variables have the highest correlation with Mental wellbeing?

# %%
df2.corr()
# Out:
#                                Rank  Young adult population      Rent  \
# Rank                       1.000000               -0.470033  0.008823
# Young adult population    -0.470033                1.000000 -0.017199
# Rent                       0.008823               -0.017199  1.000000
# Salary                    -0.421002               -0.104809  0.644987
# Mental wellbeing          -0.413355                0.144583  0.433131
# 4G coverage               -0.349149                0.103711  0.268219
# Nightlife                 -0.425728                0.136514 -0.065455
# Total Score / 100         -0.985326                0.447478 -0.006664
# Percent of Salary on Rent  0.136871                0.034250  0.944887
#
#                              Salary  Mental wellbeing  4G coverage  Nightlife  \
# Rank                      -0.421002         -0.413355    -0.349149  -0.425728
# Young adult population    -0.104809          0.144583     0.103711   0.136514
# Rent                       0.644987          0.433131     0.268219  -0.065455
# Salary                     1.000000          0.212773     0.085814  -0.018722
# Mental wellbeing           0.212773          1.000000     0.229536   0.191729
# 4G coverage                0.085814          0.229536     1.000000   0.000764
# Nightlife                 -0.018722          0.191729     0.000764   1.000000
# Total Score / 100          0.438366          0.414249     0.364725   0.434517
# Percent of Salary on Rent  0.379133          0.529396     0.275997  -0.051880
#
#                            Total Score / 100  Percent of Salary on Rent
# Rank                               -0.985326                   0.136871
# Young adult population              0.447478                   0.034250
# Rent                               -0.006664                   0.944887
# Salary                              0.438366                   0.379133
# Mental wellbeing                    0.414249                   0.529396
# 4G coverage                         0.364725                   0.275997
# Nightlife                           0.434517                  -0.051880
# Total Score / 100                   1.000000                  -0.138168
# Percent of Salary on Rent          -0.138168                   1.000000

# %% [markdown]
# * Rent has a strong positive relationship with mental wellbeing, so it seems that the higher the rent of a city, the more likely it is that a person will have a higher mental wellbeing. But this is a weak correlation.
# * The strongest correlation is between Percent of Salary on Rent and Mental Wellbeing, with a pearson score of 0.529.
# * This is curious, since it would appear that a higher proportion of salary spent of rent correlates positively with a happier individual.

# %%
plt.figure(figsize=(9, 7));
plt.title('Relationship between Percent of salary spend on rent and mental wellbeing');
sns.regplot(x = 'Percent of Salary on Rent', y = 'Mental wellbeing', data = df2);

# %% [markdown]
# ### Does a higher value of rent correlate with a higher gross value added per head?

# %%
df3 = df.merge(df2, on='City', how='inner')
df3.dtypes
def convert_dtypes(col):
    gva_vals = []
    for val in col:
        gva_vals.append(val.strip('£ ').replace(',', ''))
    return gva_vals

df3
# Out:
#     Rank_x                City  GVA (£ millions)  Growth (%) 2009-15  \
# 0        1              London            378424                30.6
# 1        2          Manchester             59606                17.5
# 2        3          Birmingham             24790                21.7
# 3        4               Leeds             21260                14.6
# 4        5             Glasgow             19624                12.8
# 5        6           Edinburgh             18437                10.6
# 6        8             Bristol             13862                22.4
# 7        9           Sheffield             11300                11.2
# 8       10             Cardiff             11044                12.4
# 9       11           Liverpool             10907                 0.6
# 10      14            Bradford              9504                10.6
# 11      15          Nottingham              8816                16.8
# 12      17            Coventry              7655                31.1
# 13      18           Leicester              7473                26.1
# 14      20               Derby              6932                28.0
# 15      22         Southampton              5873                16.4
# 16      24          Portsmouth              5344                13.0
# 17      26            Plymouth              5192                20.4
# 18      27  Kingston upon Hull              5129                 4.3
# 19      29               Luton              4888                 9.0
# 20      30      Stoke-on-Trent              4763                24.0
# 21      31       Wolverhampton              4625                13.5
#
#    GVA per head GVA per employee (productivity)  Rank_y  \
# 0      £ 43,629                        £ 70,392      20
# 1      £ 21,626                        £ 44,974       4
# 2      £ 22,307                        £ 45,934      25
# 3      £ 27,466                        £ 45,790      16
# 4      £ 32,305                        £ 46,914       7
# 5      £ 36,963                        £ 55,196       1
# 6      £ 30,850                        £ 48,090       5
# 7      £ 19,833                        £ 41,695      24
# 8      £ 22,783                        £ 42,181      18
# 9      £ 22,790                        £ 43,396       8
# 10     £ 17,892                        £ 43,507      28
# 11     £ 27,645                        £ 37,948      13
# 12     £ 22,165                        £ 45,706      12
# 13     £ 21,812                        £ 40,466      21
# 14     £ 27,266                        £ 51,932       3
# 15     £ 23,535                        £ 45,882      14
# 16     £ 25,236                        £ 46,405      22
# 17     £ 19,762                        £ 40,322      11
# 18     £ 19,803                        £ 41,246      23
# 19     £ 22,766                        £ 51,701      19
# 20     £ 18,926                        £ 39,707      27
# 21     £ 18,179                        £ 42,117      26
#
#                       Region  Young adult population  Rent  Salary  \
# 0                     London                  0.2854  2059   30311
# 1                 North West                  0.3857   689   21896
# 2              West Midlands                  0.2950   702   22225
# 3   Yorkshire and the Humber                  0.2955   617   23115
# 4                   Scotland                  0.3289   714   22325
# 5                   Scotland                  0.3256   714   25720
# 6                 South West                  0.3535   829   24122
# 7   Yorkshire and the Humber                  0.3054   617   22321
# 8                      Wales                  0.3296   660   23411
# 9                 North West                  0.3265   689   22338
# 10  Yorkshire and the Humber                  0.2324   617   21126
# 11             East Midlands                  0.3789   654   19552
# 12             West Midlands                  0.3417   702   24291
# 13             East Midlands                  0.3277   654   18958
# 14             East Midlands                  0.2556   654   26000
# 15                South East                  0.3532  1101   22007
# 16                South East                  0.3244  1101   22039
# 17                South West                  0.2710   829   22526
# 18  Yorkshire and the Humber                  0.2863   617   19262
# 19                      East                  0.2634   930   21652
# 20             West Midlands                  0.2523   702   22082
# 21             West Midlands                  0.2439   702   21600
#
#     Mental wellbeing  4G coverage  Nightlife  Total Score / 100  \
# 0              25.16       0.9306          5              55.17
# 1              25.23       0.8971         10              66.13
# 2              25.00       0.8195          4              53.74
# 3              25.02       0.8089          7              58.09
# 4              25.27       0.9102         10              65.27
# 5              25.27       0.8638         12              72.05
# 6              25.28       0.8323          9              65.44
# 7              25.02       0.7346          7              53.84
# 8              25.10       0.7108          6              57.01
# 9              25.23       0.8987         13              64.96
# 10             25.02       0.7818          4              47.60
# 11             25.19       0.8824         10              60.23
# 12             25.00       0.8196          2              60.59
# 13             25.19       0.8904          7              55.14
# 14             25.19       0.8847         11              69.00
# 15             25.47       0.9026          7              60.09
# 16             25.47       0.7808          9              54.45
# 17             25.28       0.7989         27              62.12
# 18             25.02       0.9346          9              54.07
# 19             25.50       0.9029          3              55.80
# 20             25.00       0.7641          9              50.59
# 21             25.00       0.8714          6              52.11
#
#     Percent of Salary on Rent
# 0                   81.514962
# 1                   37.760322
# 2                   37.903262
# 3                   32.031149
# 4                   38.378499
# 5                   33.312597
# 6                   41.240361
# 7                   33.170557
# 8                   33.830251
# 9                   37.013161
# 10                  35.046862
# 11                  40.139116
# 12                  34.679511
# 13                  41.396772
# 14                  30.184615
# 15                  60.035443
# 16                  59.948274
# 17                  44.162301
# 18                  38.438376
# 19                  51.542583
# 20                  38.148718
# 21                  39.000000

# %% [markdown]
# ## Is there a correlation between the Young adult percentage and productivity of a city?

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x = 'Young adult population', y = 'GVA per head', data=df3);
